# %% [markdown]
# # Exercise: "Human learning" with iris data
#
# **Question:** Can you predict the species of an iris using petal and sepal measurements?
#
# 1. Read the iris data into a Pandas DataFrame, including column names.
# 2. Gather some basic information about the data.
# 3. Use sorting, split-apply-combine, and/or visualization to look for differences between species.
# 4. Write down a set of rules that could be used to predict species based on iris measurements.
#
# **BONUS:** Define a function that accepts a row of data and returns a predicted species. Then, use that function to make predictions for all existing rows of data, and check the accuracy of your predictions.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# display plots in the notebook
# %matplotlib inline

# increase default figure and font sizes for easier viewing
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# ## Task 1
#
# Read the iris data into a pandas DataFrame, including column names.

# %%
iris_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
irisData=pd.read_table('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=0, names=iris_cols, sep=',')
irisData.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# ## Task 2
#
# Gather some basic information about the data.

# %%
#irisData.shape
#irisData.index
#irisData.dtypes
irisData.columns
# Out:
# Index([u'sepal_length', u'sepal_width', u'petal_length', u'petal_width',
#        u'species'],
#       dtype='object')

# %% [markdown]
# ## Task 3
#
# Use sorting, split-apply-combine, and/or visualization to look for differences between species.

# %%
#irisData.groupby('species').sepal_length.mean()
#irisData.groupby('species').sepal_width.mean()
#irisData.groupby('species').petal_length.mean()
#irisData.groupby('species').petal_width.mean()

irisData.species.value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        49
# dtype: int64

# %% [markdown]
# ### sorting

# %%
#irisData.species.describe()
#irisData.species.value_counts()
#irisData.species.sort

#irisData.sort('sepal_width',ascending=False, inplace=True)
#irisData.sort('sepal_width',ascending=False, inplace=True)
#irisData.sort('petal_length',ascending=False, inplace=True)
#Petal Length gets me all the IRIS Data's Correctly for Virginica. 
#irisData.sort('petal_width',ascending=False, inplace=True)

irisData.sort('petal_length',ascending=False, inplace=True)
VirginicaData=irisData[(irisData.petal_length>4.5) & (irisData.petal_width>1.7)]

VirginicaData.species.value_counts()
# Out:
# Iris-virginica     45
# Iris-versicolor     1
# dtype: int64

# %% [markdown]
# ### split-apply-combine

# %%
#irisData.groupby('species').sepal_width.mean()
#irisData.groupby('species').sepal_length.mean()
SetosaData=irisData[irisData.petal_width<1.0]
SetosaData.species.value_counts()
#SetosaData

irisData.groupby('species').petal_width.mean()
SetosaData=irisData[irisData.petal_width<1.0]
SetosaData.species.value_counts()
#irisData.groupby('species').sepal_width.mean()

# %% [markdown]
# ### visualization

# %%
irisData.describe()
irisData.groupby('species').describe()

irisData.sort('species').values

# compare with scatter plot

#irisData.groupby('species').sepal_length.mean().plot(kind='bar')
#irisData.groupby('species').sepal_width.mean().plot(kind='bar')
#irisData.groupby('species').petal_length.mean().plot(kind='bar')
#irisData.groupby('species').petal_width.mean().plot(kind='bar')

irisData.boxplot(column='petal_width', by='species')
#irisData.boxplot(column='petal_length', by='species')

# %% [markdown]
# ## Task 4
#
# Write down a set of rules that could be used to predict species based on iris measurements.

# %%
versicolorData=irisData[(irisData.petal_width<1.8) & (irisData.petal_length<5.2) & (irisData.petal_length>3) ]
versicolorData.species.value_counts()
#SetosaData

#irisData.groupby('species').petal_width.mean()
#SetosaData=irisData[irisData.petal_width<1.0]
#SetosaData.species.value_counts()
#irisData.groupby('species').sepal_width.mean()

# %% [markdown]
# ## Bonus
#
# Define a function that accepts a row of data and returns a predicted species. Then, use that function to make predictions for all existing rows of data, and check the accuracy of your predictions.

# %%
VirginicaData=irisData[(irisData.petal_length>4.5) & (irisData.petal_width>1.7)]
versicolorData=irisData[(irisData.petal_width<1.8) & (irisData.petal_length<5.2) & (irisData.petal_length>3) ]
SetosaData=irisData[irisData.petal_width<1.0]

irisData.head(5)

# %%
irisData['PredictedSpecies']="Blank"
irisData['YangCorrect']="UndeterminedCorrect"

def predict(sepal_length,sepal_width,pedal_length,pedal_width):
    if pedal_width < 1.0:
        return 'Iris-setosa'
    elif (pedal_length > 4.5) & (pedal_width > 1.7):
        return 'Iris-virginica'
    elif ( pedal_length<5.2) & (pedal_length > 3) & (pedal_width < 1.8):
        return 'Iris-versicolor'
    else:
        return 'Yang messed up'

# %%
#predict(irisData.iloc[0][0],irisData.iloc[0][1],irisData.iloc[0][2],irisData.iloc[0][3])

irisData.head(5)

# %%
for index, row in irgisData.iterrows():
    row[5]=predict(row[0],row[1],row[2],row[3])
    if row[4]==row[5]:
        row[6]="YangCorrect"
    else:
        row[6]="YangIncorrect"
    irisData.iloc[index][5]=row[5]
    irisData.iloc[index][6]=row[6]
    #print str(index) + " Predicted: " + row[5] + " Actual: " + row[4] + " Yang Accuracy: "+ row[6]
# Out:
# C:\Users\Brittany\Anaconda\lib\site-packages\IPython\kernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Brittany\Anaconda\lib\site-packages\IPython\kernel\__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
irisData.head(50)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width          species  \
# 117           7.7          2.6           6.9          2.3   Iris-virginica
# 121           7.7          2.8           6.7          2.0   Iris-virginica
# 116           7.7          3.8           6.7          2.2   Iris-virginica
# 104           7.6          3.0           6.6          2.1   Iris-virginica
# 130           7.9          3.8           6.4          2.0   Iris-virginica
# 106           7.3          2.9           6.3          1.8   Iris-virginica
# 129           7.4          2.8           6.1          1.9   Iris-virginica
# 108           7.2          3.6           6.1          2.5   Iris-virginica
# 134           7.7          3.0           6.1          2.3   Iris-virginica
# 99            6.3          3.3           6.0          2.5   Iris-virginica
# 124           7.2          3.2           6.0          1.8   Iris-virginica
# ...
